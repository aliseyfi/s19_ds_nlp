# %%
script = open("/Users/teacher/repos/s19_ds_nlp/Untitled Folder/thor_script.txt","r")
script_lines = script

# %%
# Out:
# Thor Ragnarok Script at IMSDb.
#
#
#                                THOR: RAGNAROK
#
#
#
#
#                                  Written by
#
#              Eric Pearson and Craig Kyle & Christopher L. Yost
#
#
#
#
#
#
#
#  1    OMITTED                                                         1
#
# A2   OMITTED                                                         A2
#
# A3   THE MARVEL LOGO. SMOLDERING, BEGINNING TO TURN ORANGE IN THE    A3
#      HEAT AS WE TILT UP TO SEE-
#
#      -FIRE.    NOTHING BUT FIRE.
#
# 2    INT. TIGHT SPACE - INDETERMINATE TIME                           2
#
#      Dark and cramped. The soft red light of fire seeps through
#      iron slats. Inside this cage is a man, bound by chains.
#
#      It's THOR. His beard is long and his clothes are worn. That
#      rough, grizzled look of a man who's spent years on the road.
#
#      He awakens with a JOLT.   Looks around.
#
#                            THOR
#                  Now I know what you're thinking.
# ...

# %%
script = open("/Users/teacher/repos/s19_ds_nlp/Untitled Folder/thor_script.txt","r")
script_lines = script

character_speech = []

string_store = ""
in_character = False

for line in script_lines:
    #print(len(line.strip()), " -- ", len(line.split(" ")), " -- ", line)
    if line.count(" ") > 23 and line.count(" ") < 31:
        #print(line.count(" "), " -- ", line)
        character_speech.append(string_store)
        string_store = ""
        string_store += line
    else:
        #character_speech.append(line)
        string_store += line

for i in character_speech:
    print(i)
    print("^" * 25)
# Out:
# Thor Ragnarok Script at IMSDb.
#
#
#                                THOR: RAGNAROK
#
#
#
#
#                                  Written by
#
#              Eric Pearson and Craig Kyle & Christopher L. Yost
#
#
#
#
#
#
#
#  1    OMITTED                                                         1
#
# A2   OMITTED                                                         A2
#
# A3   THE MARVEL LOGO. SMOLDERING, BEGINNING TO TURN ORANGE IN THE    A3
#      HEAT AS WE TILT UP TO SEE-
#
#      -FIRE.    NOTHING BUT FIRE.
#
# 2    INT. TIGHT SPACE - INDETERMINATE TIME                           2
#
#      Dark and cramped. The soft red light of fire seeps through
#      iron slats. Inside this cage is a man, bound by chains.
#
#      It's THOR. His beard is long and his clothes are worn. That
#      rough, grizzled look of a man who's spent years on the road.
#
#      He awakens with a JOLT.   Looks around.
#
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^
#                            THOR
# ...
